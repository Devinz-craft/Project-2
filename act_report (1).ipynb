# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### This report contains results from the analysis of a Twitter account @WeRateDogs .

# %% [markdown]
# >For the analysis to be made we got data from three different datasets which involved the cleaning and gathering data from each column to one master dataset.

# %% [markdown]
# The datasets that were gathered are as follows :
# >twitter_archive_enhanced.csv
#
# >image_prediction.tsv
#
# >tweeet_json_text

# %% [markdown]
# ###### The master dataset where our analysis was done on was named "twitter_archive _master"

# %% [markdown]
# ###### Importing our actions which were used for analysis to help for better understanding

# %%
import pandas as pd
data = pd.read_csv("twitter_archive_master.csv")

# %%
data.describe().T
# Out:
#                    count          mean           std           min  \
# tweet_id          2073.0  7.383634e+17  6.780118e+16  6.660209e+17
# rating_numerator  2073.0  1.226580e+01  4.069992e+01  0.000000e+00
# img_num           2073.0  1.203570e+00  5.618561e-01  1.000000e+00
# p1_conf           2073.0  5.945317e-01  2.712345e-01  4.433340e-02
# p2_conf           2073.0  1.346665e-01  1.006830e-01  1.011300e-08
# p3_conf           2073.0  6.034005e-02  5.092769e-02  1.740170e-10
# favorite_count    2073.0  8.556718e+03  1.209864e+04  0.000000e+00
# retweet_count     2073.0  2.976089e+03  5.054898e+03  1.600000e+01
#
#                            25%           50%           75%           max
# tweet_id          6.764706e+17  7.119681e+17  7.931959e+17  8.924206e+17
# rating_numerator  1.000000e+01  1.100000e+01  1.200000e+01  1.776000e+03
# img_num           1.000000e+00  1.000000e+00  1.000000e+00  4.000000e+00
# ...

# %% [markdown]
# The table is statistical result of  columns  in the twitter_archive_master dataset.This column only analyzes columns that have integers or numbers as values .
# >From the above table its clear to say that favorite_count has a maximum  value of 132,810.0 and a minmum value of 0.
#
# >The highest image number is 4 and minimum is 1
#
# >For the retweet count the highest count is 79,515 and the lowest was 16

# %%
data.corr()
# Out:
#                   tweet_id  rating_numerator   img_num   p1_conf    p1_dog  \
# tweet_id          1.000000          0.023103  0.205455  0.101283  0.111304
# rating_numerator  0.023103          1.000000 -0.000405 -0.009143 -0.028515
# img_num           0.205455         -0.000405  1.000000  0.203071  0.026060
# p1_conf           0.101283         -0.009143  0.203071  1.000000  0.118777
# p1_dog            0.111304         -0.028515  0.026060  0.118777  1.000000
# p2_conf           0.003047         -0.020317 -0.159690 -0.511547  0.112147
# p2_dog            0.112607         -0.033740  0.045653  0.131969  0.634661
# p3_dog            0.087844         -0.028497  0.059565  0.109022  0.555778
# p3_conf          -0.042979         -0.003887 -0.139454 -0.709583  0.048809
# favorite_count    0.607007          0.010157  0.132241  0.076077  0.056156
# retweet_count     0.404702          0.012787  0.105534  0.044739  0.006092
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(), annot=True);

# %% [markdown]
# The two diagrams show how each and every column corrolate with each eachother.The are both revealing the same thing but the latter is in a  diagrammatic form which helps more for better visual assesment.

# %% [markdown]
# >In the first result the concept to reading and uderstanding which have the highest correlation is check for the positive and negatively correlated columns ie(-000.1 or 0.928) , the positively affected shows great correlation while negative shows low coorelation .For example the retweet_count and favorite count are positively corrolated with a corrolation number of 0.79.

# %% [markdown]
# > In the Second result follows the same concept as the first one but the only difference being that the avalaibility of colour shading i.e the lighter the colour shade ,the higher the correlation .The same goes vice-versa where the darker shade show low correlation .

# %% [markdown]
# ###### . General Overview Analysis
# > After series of investigations programmatically I noticed that the tweet_id highly influence the favorite_count and retweet_count ,this might due to the fact that the user that was designated to that tweet_id either have more public views on their post i.e(having a lot of  followers on twitter ) and maybe known for their love for dogs. Also the dog stage affects the  dog rating and I found that a doogo transitionin into a puppo has the highest rating_numerator.
